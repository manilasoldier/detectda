# %% [markdown]
# In the below, <code>test_video.pkl</code> is the output of the "identify_polygon" python script, <br>
# which allows choose your desired polygonal subregion.

# %%
from skimage import io, filters
import detectda as dtda
import numpy as np
import pickle
import matplotlib.pyplot as plt
import cv2

F = open('test_video.pkl', 'rb')
E = pickle.load(F)
tv, polygon = E['video'], E['polygon']
print(tv.shape)
# Out:
# (120, 252, 412)

# %%
impol = dtda.ImageSeries(tv, polygon, n_jobs=2)
impol.fit(sigma=2)
# Out:
# Video processed in 46.1041 seconds

# %%
impol.get_alps()
impol.get_pers_entr()

# %%
plt.plot(impol.pers_entr)

# %%
plt.plot(impol.alps)

# %% [markdown]
# Let's now examine our video by plotting a frame of the already processed video (which consists of X frames, Y rows, and Z columns after processing). Do the fluctuations in the above plots correspond to anything interesting happening in the video?

# %%
frame =  36
plt.imshow(filters.gaussian(tv[frame], 2), "gray")
